# %%
# !pip install recbole

# %%
import os
from pathlib import Path

os.chdir('/content/drive/MyDrive/hnm')
DATA_PATH = Path.cwd() / 'data'
RAW = DATA_PATH / 'raw'
PROCESSED = DATA_PATH / 'processed'
SUBMISSION = DATA_PATH / 'submission'

import numpy as np
import pandas as pd

import logging
from logging import getLogger
from recbole.config import Config
from recbole.data import create_dataset, data_preparation
from recbole.model.sequential_recommender import SASRec
from recbole.trainer import Trainer
from recbole.utils import init_seed, init_logger

from tqdm import tqdm

# %%
os.chdir('/content/drive/MyDrive/hnm/sasrec')

# %%
parameter_dict = {
    'data_path': PROCESSED,
    'USER_ID_FIELD': 'user_id',
    'ITEM_ID_FIELD': 'item_id',
    'TIME_FIELD': 'timestamp',
    'user_inter_num_interval': "[30,inf)",
    'item_inter_num_interval': "[30,inf)",
    'load_col': {'inter': ['user_id', 'item_id', 'timestamp']},
    'neg_sampling': None,
    'epochs': 50,
    'metrics': ['MAP'],
    'valid_metric': 'MAP@12',
    'topk': [12],
    'eval_args': {
        'split': {'RS': [9, 0, 1]},
        'group_by': 'user',
        'order': 'TO',
        'mode': 'full'},
    'learning_rate': 0.01,
    'train_batch_size': 4096,
    'eval_batch_size': 4096
}

config = Config(model='SASRec', dataset='recbox_data', config_dict=parameter_dict)

# init random seed
init_seed(config['seed'], config['reproducibility'])

# logger initialization
init_logger(config)
logger = getLogger()
# Create handlers
c_handler = logging.StreamHandler()
c_handler.setLevel(logging.INFO)
logger.addHandler(c_handler)

# write config info into log
logger.info(config)
# Out:
# 30 Mar 13:29    INFO
# General Hyper Parameters:
# gpu_id = 0
# use_gpu = True
# seed = 2020
# state = INFO
# reproducibility = True
# data_path = /content/drive/MyDrive/hnm/data/processed/recbox_data
# checkpoint_dir = saved
# show_progress = True
# save_dataset = False
# dataset_save_path = None
# save_dataloaders = False
# dataloaders_save_path = None
# log_wandb = False
#
# Training Hyper Parameters:
# epochs = 50
# train_batch_size = 4096
# learner = adam
# learning_rate = 0.01
# neg_sampling = None
# eval_step = 1
# stopping_step = 10
# clip_grad_norm = None
# weight_decay = 0.0
# loss_decimal_place = 4
#
# Evaluation Hyper Parameters:
# eval_args = {'split': {'RS': [9, 0, 1]}, 'group_by': 'user', 'order': 'TO', 'mode': 'full'}
# repeatable = True
# metrics = ['MAP']
# topk = [12]
# valid_metric = MAP@12
# valid_metric_bigger = True
# eval_batch_size = 4096
# metric_decimal_place = 4
#
# Dataset Hyper Parameters:
# field_separator =
# seq_separator =
# USER_ID_FIELD = user_id
# ITEM_ID_FIELD = item_id
# RATING_FIELD = rating
# TIME_FIELD = timestamp
# seq_len = None
# LABEL_FIELD = label
# threshold = None
# NEG_PREFIX = neg_
# load_col = {'inter': ['user_id', 'item_id', 'timestamp']}
# unload_col = None
# unused_col = None
# additional_feat_suffix = None
# rm_dup_inter = None
# val_interval = None
# filter_inter_by_user_or_item = True
# user_inter_num_interval = [30,inf)
# item_inter_num_interval = [30,inf)
# alias_of_user_id = None
# alias_of_item_id = None
# alias_of_entity_id = None
# alias_of_relation_id = None
# preload_weight = None
# normalize_field = None
# normalize_all = None
# ITEM_LIST_LENGTH_FIELD = item_length
# LIST_SUFFIX = _list
# MAX_ITEM_LIST_LENGTH = 50
# POSITION_FIELD = position_id
# HEAD_ENTITY_ID_FIELD = head_id
# TAIL_ENTITY_ID_FIELD = tail_id
# RELATION_ID_FIELD = relation_id
# ENTITY_ID_FIELD = entity_id
# benchmark_filename = None
#
# Other Hyper Parameters:
# wandb_project = recbole
# require_pow = False
# n_layers = 2
# n_heads = 2
# hidden_size = 64
# inner_size = 256
# hidden_dropout_prob = 0.5
# attn_dropout_prob = 0.5
# hidden_act = gelu
# layer_norm_eps = 1e-12
# initializer_range = 0.02
# loss_type = CE
# MODEL_TYPE = ModelType.SEQUENTIAL
# MODEL_INPUT_TYPE = InputType.POINTWISE
# eval_type = EvaluatorType.RANKING
# device = cuda
# train_neg_sample_args = {'strategy': 'none'}
# eval_neg_sample_args = {'strategy': 'full', 'distribution': 'uniform'}
#
#
#
# General Hyper Parameters:
# gpu_id = 0
# use_gpu = True
# seed = 2020
# state = INFO
# reproducibility = True
# data_path = /content/drive/MyDrive/hnm/data/processed/recbox_data
# checkpoint_dir = saved
# show_progress = True
# save_dataset = False
# dataset_save_path = None
# save_dataloaders = False
# dataloaders_save_path = None
# log_wandb = False
#
# Training Hyper Parameters:
# epochs = 50
# train_batch_size = 4096
# learner = adam
# learning_rate = 0.01
# neg_sampling = None
# eval_step = 1
# stopping_step = 10
# clip_grad_norm = None
# weight_decay = 0.0
# loss_decimal_place = 4
#
# Evaluation Hyper Parameters:
# eval_args = {'split': {'RS': [9, 0, 1]}, 'group_by': 'user', 'order': 'TO', 'mode': 'full'}
# repeatable = True
# metrics = ['MAP']
# topk = [12]
# valid_metric = MAP@12
# valid_metric_bigger = True
# eval_batch_size = 4096
# metric_decimal_place = 4
#
# Dataset Hyper Parameters:
# field_separator =
# seq_separator =
# USER_ID_FIELD = user_id
# ITEM_ID_FIELD = item_id
# RATING_FIELD = rating
# TIME_FIELD = timestamp
# seq_len = None
# LABEL_FIELD = label
# threshold = None
# NEG_PREFIX = neg_
# load_col = {'inter': ['user_id', 'item_id', 'timestamp']}
# unload_col = None
# unused_col = None
# additional_feat_suffix = None
# rm_dup_inter = None
# val_interval = None
# filter_inter_by_user_or_item = True
# user_inter_num_interval = [30,inf)
# item_inter_num_interval = [30,inf)
# alias_of_user_id = None
# alias_of_item_id = None
# alias_of_entity_id = None
# alias_of_relation_id = None
# preload_weight = None
# normalize_field = None
# normalize_all = None
# ITEM_LIST_LENGTH_FIELD = item_length
# LIST_SUFFIX = _list
# MAX_ITEM_LIST_LENGTH = 50
# POSITION_FIELD = position_id
# HEAD_ENTITY_ID_FIELD = head_id
# TAIL_ENTITY_ID_FIELD = tail_id
# RELATION_ID_FIELD = relation_id
# ENTITY_ID_FIELD = entity_id
# benchmark_filename = None
#
# Other Hyper Parameters:
# wandb_project = recbole
# require_pow = False
# n_layers = 2
# n_heads = 2
# hidden_size = 64
# inner_size = 256
# hidden_dropout_prob = 0.5
# attn_dropout_prob = 0.5
# hidden_act = gelu
# layer_norm_eps = 1e-12
# initializer_range = 0.02
# loss_type = CE
# MODEL_TYPE = ModelType.SEQUENTIAL
# MODEL_INPUT_TYPE = InputType.POINTWISE
# eval_type = EvaluatorType.RANKING
# device = cuda
# train_neg_sample_args = {'strategy': 'none'}
# eval_neg_sample_args = {'strategy': 'full', 'distribution': 'uniform'}
#
#
#
# General Hyper Parameters:
# gpu_id = 0
# use_gpu = True
# seed = 2020
# state = INFO
# reproducibility = True
# data_path = /content/drive/MyDrive/hnm/data/processed/recbox_data
# checkpoint_dir = saved
# show_progress = True
# save_dataset = False
# dataset_save_path = None
# save_dataloaders = False
# dataloaders_save_path = None
# log_wandb = False
#
# Training Hyper Parameters:
# epochs = 50
# train_batch_size = 4096
# learner = adam
# learning_rate = 0.01
# neg_sampling = None
# eval_step = 1
# stopping_step = 10
# clip_grad_norm = None
# weight_decay = 0.0
# loss_decimal_place = 4
#
# Evaluation Hyper Parameters:
# eval_args = {'split': {'RS': [9, 0, 1]}, 'group_by': 'user', 'order': 'TO', 'mode': 'full'}
# repeatable = True
# metrics = ['MAP']
# topk = [12]
# valid_metric = MAP@12
# valid_metric_bigger = True
# eval_batch_size = 4096
# metric_decimal_place = 4
#
# Dataset Hyper Parameters:
# field_separator =
# seq_separator =
# USER_ID_FIELD = user_id
# ITEM_ID_FIELD = item_id
# RATING_FIELD = rating
# TIME_FIELD = timestamp
# seq_len = None
# LABEL_FIELD = label
# threshold = None
# NEG_PREFIX = neg_
# load_col = {'inter': ['user_id', 'item_id', 'timestamp']}
# unload_col = None
# unused_col = None
# additional_feat_suffix = None
# rm_dup_inter = None
# val_interval = None
# filter_inter_by_user_or_item = True
# user_inter_num_interval = [30,inf)
# item_inter_num_interval = [30,inf)
# alias_of_user_id = None
# alias_of_item_id = None
# alias_of_entity_id = None
# alias_of_relation_id = None
# preload_weight = None
# normalize_field = None
# normalize_all = None
# ITEM_LIST_LENGTH_FIELD = item_length
# LIST_SUFFIX = _list
# MAX_ITEM_LIST_LENGTH = 50
# POSITION_FIELD = position_id
# HEAD_ENTITY_ID_FIELD = head_id
# TAIL_ENTITY_ID_FIELD = tail_id
# RELATION_ID_FIELD = relation_id
# ENTITY_ID_FIELD = entity_id
# benchmark_filename = None
#
# Other Hyper Parameters:
# wandb_project = recbole
# require_pow = False
# n_layers = 2
# n_heads = 2
# hidden_size = 64
# inner_size = 256
# hidden_dropout_prob = 0.5
# attn_dropout_prob = 0.5
# hidden_act = gelu
# layer_norm_eps = 1e-12
# initializer_range = 0.02
# loss_type = CE
# MODEL_TYPE = ModelType.SEQUENTIAL
# MODEL_INPUT_TYPE = InputType.POINTWISE
# eval_type = EvaluatorType.RANKING
# device = cuda
# train_neg_sample_args = {'strategy': 'none'}
# eval_neg_sample_args = {'strategy': 'full', 'distribution': 'uniform'}

# %%
dataset = create_dataset(config)
logger.info(dataset)
# Out:
# 30 Mar 13:34    INFO  recbox_data
# The number of users: 306733
# Average actions of users: 72.26853735508521
# The number of items: 59157
# Average actions of items: 374.72231050104807
# The number of inters: 22167073
# The sparsity of the dataset: 99.8778364322941%
# Remain Fields: ['user_id', 'item_id', 'timestamp']
# recbox_data
# The number of users: 306733
# Average actions of users: 72.26853735508521
# The number of items: 59157
# Average actions of items: 374.72231050104807
# The number of inters: 22167073
# The sparsity of the dataset: 99.8778364322941%
# Remain Fields: ['user_id', 'item_id', 'timestamp']
# recbox_data
# The number of users: 306733
# Average actions of users: 72.26853735508521
# The number of items: 59157
# Average actions of items: 374.72231050104807
# The number of inters: 22167073
# The sparsity of the dataset: 99.8778364322941%
# Remain Fields: ['user_id', 'item_id', 'timestamp']

# %%
train_data, valid_data, test_data = data_preparation(config, dataset)
# Out:
# 30 Mar 13:39    INFO  [Training]: train_batch_size = [4096] negative sampling: [None]
# [Training]: train_batch_size = [4096] negative sampling: [None]
# [Training]: train_batch_size = [4096] negative sampling: [None]
# 30 Mar 13:39    INFO  [Evaluation]: eval_batch_size = [4096] eval_args: [{'split': {'RS': [9, 0, 1]}, 'group_by': 'user', 'order': 'TO', 'mode': 'full'}]
# [Evaluation]: eval_batch_size = [4096] eval_args: [{'split': {'RS': [9, 0, 1]}, 'group_by': 'user', 'order': 'TO', 'mode': 'full'}]
# [Evaluation]: eval_batch_size = [4096] eval_args: [{'split': {'RS': [9, 0, 1]}, 'group_by': 'user', 'order': 'TO', 'mode': 'full'}]

# %%
model = SASRec(config, train_data.dataset).to(config['device'])
logger.info(model)
# Out:
# 30 Mar 13:39    INFO  SASRec(
#   (item_embedding): Embedding(59157, 64, padding_idx=0)
#   (position_embedding): Embedding(50, 64)
#   (trm_encoder): TransformerEncoder(
#     (layer): ModuleList(
#       (0): TransformerLayer(
#         (multi_head_attention): MultiHeadAttention(
#           (query): Linear(in_features=64, out_features=64, bias=True)
#           (key): Linear(in_features=64, out_features=64, bias=True)
#           (value): Linear(in_features=64, out_features=64, bias=True)
#           (softmax): Softmax(dim=-1)
#           (attn_dropout): Dropout(p=0.5, inplace=False)
#           (dense): Linear(in_features=64, out_features=64, bias=True)
#           (LayerNorm): LayerNorm((64,), eps=1e-12, elementwise_affine=True)
#           (out_dropout): Dropout(p=0.5, inplace=False)
#         )
#         (feed_forward): FeedForward(
#           (dense_1): Linear(in_features=64, out_features=256, bias=True)
#           (dense_2): Linear(in_features=256, out_features=64, bias=True)
#           (LayerNorm): LayerNorm((64,), eps=1e-12, elementwise_affine=True)
#           (dropout): Dropout(p=0.5, inplace=False)
#         )
#       )
#       (1): TransformerLayer(
#         (multi_head_attention): MultiHeadAttention(
#           (query): Linear(in_features=64, out_features=64, bias=True)
#           (key): Linear(in_features=64, out_features=64, bias=True)
#           (value): Linear(in_features=64, out_features=64, bias=True)
#           (softmax): Softmax(dim=-1)
#           (attn_dropout): Dropout(p=0.5, inplace=False)
#           (dense): Linear(in_features=64, out_features=64, bias=True)
#           (LayerNorm): LayerNorm((64,), eps=1e-12, elementwise_affine=True)
#           (out_dropout): Dropout(p=0.5, inplace=False)
#         )
#         (feed_forward): FeedForward(
#           (dense_1): Linear(in_features=64, out_features=256, bias=True)
#           (dense_2): Linear(in_features=256, out_features=64, bias=True)
#           (LayerNorm): LayerNorm((64,), eps=1e-12, elementwise_affine=True)
#           (dropout): Dropout(p=0.5, inplace=False)
#         )
#       )
#     )
#   )
#   (LayerNorm): LayerNorm((64,), eps=1e-12, elementwise_affine=True)
#   (dropout): Dropout(p=0.5, inplace=False)
#   (loss_fct): CrossEntropyLoss()
# )
# Trainable parameters: 3889344
# SASRec(
#   (item_embedding): Embedding(59157, 64, padding_idx=0)
#   (position_embedding): Embedding(50, 64)
#   (trm_encoder): TransformerEncoder(
#     (layer): ModuleList(
#       (0): TransformerLayer(
#         (multi_head_attention): MultiHeadAttention(
#           (query): Linear(in_features=64, out_features=64, bias=True)
#           (key): Linear(in_features=64, out_features=64, bias=True)
#           (value): Linear(in_features=64, out_features=64, bias=True)
#           (softmax): Softmax(dim=-1)
#           (attn_dropout): Dropout(p=0.5, inplace=False)
#           (dense): Linear(in_features=64, out_features=64, bias=True)
#           (LayerNorm): LayerNorm((64,), eps=1e-12, elementwise_affine=True)
#           (out_dropout): Dropout(p=0.5, inplace=False)
#         )
#         (feed_forward): FeedForward(
#           (dense_1): Linear(in_features=64, out_features=256, bias=True)
#           (dense_2): Linear(in_features=256, out_features=64, bias=True)
#           (LayerNorm): LayerNorm((64,), eps=1e-12, elementwise_affine=True)
#           (dropout): Dropout(p=0.5, inplace=False)
#         )
#       )
#       (1): TransformerLayer(
#         (multi_head_attention): MultiHeadAttention(
#           (query): Linear(in_features=64, out_features=64, bias=True)
#           (key): Linear(in_features=64, out_features=64, bias=True)
#           (value): Linear(in_features=64, out_features=64, bias=True)
#           (softmax): Softmax(dim=-1)
#           (attn_dropout): Dropout(p=0.5, inplace=False)
#           (dense): Linear(in_features=64, out_features=64, bias=True)
#           (LayerNorm): LayerNorm((64,), eps=1e-12, elementwise_affine=True)
#           (out_dropout): Dropout(p=0.5, inplace=False)
#         )
#         (feed_forward): FeedForward(
#           (dense_1): Linear(in_features=64, out_features=256, bias=True)
#           (dense_2): Linear(in_features=256, out_features=64, bias=True)
#           (LayerNorm): LayerNorm((64,), eps=1e-12, elementwise_affine=True)
#           (dropout): Dropout(p=0.5, inplace=False)
#         )
#       )
#     )
#   )
#   (LayerNorm): LayerNorm((64,), eps=1e-12, elementwise_affine=True)
#   (dropout): Dropout(p=0.5, inplace=False)
#   (loss_fct): CrossEntropyLoss()
# )
# Trainable parameters: 3889344
# SASRec(
#   (item_embedding): Embedding(59157, 64, padding_idx=0)
#   (position_embedding): Embedding(50, 64)
#   (trm_encoder): TransformerEncoder(
#     (layer): ModuleList(
#       (0): TransformerLayer(
#         (multi_head_attention): MultiHeadAttention(
#           (query): Linear(in_features=64, out_features=64, bias=True)
#           (key): Linear(in_features=64, out_features=64, bias=True)
#           (value): Linear(in_features=64, out_features=64, bias=True)
#           (softmax): Softmax(dim=-1)
#           (attn_dropout): Dropout(p=0.5, inplace=False)
#           (dense): Linear(in_features=64, out_features=64, bias=True)
#           (LayerNorm): LayerNorm((64,), eps=1e-12, elementwise_affine=True)
#           (out_dropout): Dropout(p=0.5, inplace=False)
#         )
#         (feed_forward): FeedForward(
#           (dense_1): Linear(in_features=64, out_features=256, bias=True)
#           (dense_2): Linear(in_features=256, out_features=64, bias=True)
#           (LayerNorm): LayerNorm((64,), eps=1e-12, elementwise_affine=True)
#           (dropout): Dropout(p=0.5, inplace=False)
#         )
#       )
#       (1): TransformerLayer(
#         (multi_head_attention): MultiHeadAttention(
#           (query): Linear(in_features=64, out_features=64, bias=True)
#           (key): Linear(in_features=64, out_features=64, bias=True)
#           (value): Linear(in_features=64, out_features=64, bias=True)
#           (softmax): Softmax(dim=-1)
#           (attn_dropout): Dropout(p=0.5, inplace=False)
#           (dense): Linear(in_features=64, out_features=64, bias=True)
#           (LayerNorm): LayerNorm((64,), eps=1e-12, elementwise_affine=True)
#           (out_dropout): Dropout(p=0.5, inplace=False)
#         )
#         (feed_forward): FeedForward(
#           (dense_1): Linear(in_features=64, out_features=256, bias=True)
#           (dense_2): Linear(in_features=256, out_features=64, bias=True)
#           (LayerNorm): LayerNorm((64,), eps=1e-12, elementwise_affine=True)
#           (dropout): Dropout(p=0.5, inplace=False)
#         )
#       )
#     )
#   )
#   (LayerNorm): LayerNorm((64,), eps=1e-12, elementwise_affine=True)
#   (dropout): Dropout(p=0.5, inplace=False)
#   (loss_fct): CrossEntropyLoss()
# )
# Trainable parameters: 3889344

# %%
trainer = Trainer(config, model)

best_valid_score, best_valid_result = trainer.fit(train_data, valid_data=valid_data, show_progress=True)
# Out:
# Train     0: 100%|█████████████████████| 4837/4837 [15:59<00:00,  5.04it/s, GPU RAM: 7.33 G/15.78 G]
# 30 Mar 13:55    INFO  epoch 0 training [time: 959.80s, train loss: 41748.3684]
# epoch 0 training [time: 959.80s, train loss: 41748.3684]
# epoch 0 training [time: 959.80s, train loss: 41748.3684]
# 30 Mar 13:55    INFO  Saving current: saved/SASRec-Mar-30-2022_13-39-54.pth
# Saving current: saved/SASRec-Mar-30-2022_13-39-54.pth
# Saving current: saved/SASRec-Mar-30-2022_13-39-54.pth
# Train     1: 100%|█████████████████████| 4837/4837 [16:07<00:00,  5.00it/s, GPU RAM: 7.33 G/15.78 G]
# 30 Mar 14:12    INFO  epoch 1 training [time: 967.07s, train loss: 40313.5844]
# epoch 1 training [time: 967.07s, train loss: 40313.5844]
# epoch 1 training [time: 967.07s, train loss: 40313.5844]
# 30 Mar 14:12    INFO  Saving current: saved/SASRec-Mar-30-2022_13-39-54.pth
# Saving current: saved/SASRec-Mar-30-2022_13-39-54.pth
# Saving current: saved/SASRec-Mar-30-2022_13-39-54.pth
# Train     2: 100%|█████████████████████| 4837/4837 [16:08<00:00,  5.00it/s, GPU RAM: 7.33 G/15.78 G]
# 30 Mar 14:28    INFO  epoch 2 training [time: 968.08s, train loss: 40005.8156]
# epoch 2 training [time: 968.08s, train loss: 40005.8156]
# epoch 2 training [time: 968.08s, train loss: 40005.8156]
# 30 Mar 14:28    INFO  Saving current: saved/SASRec-Mar-30-2022_13-39-54.pth
# Saving current: saved/SASRec-Mar-30-2022_13-39-54.pth
# Saving current: saved/SASRec-Mar-30-2022_13-39-54.pth
# Train     3: 100%|█████████████████████| 4837/4837 [15:56<00:00,  5.06it/s, GPU RAM: 7.33 G/15.78 G]
# 30 Mar 14:44    INFO  epoch 3 training [time: 956.60s, train loss: 39837.8072]
# epoch 3 training [time: 956.60s, train loss: 39837.8072]
# epoch 3 training [time: 956.60s, train loss: 39837.8072]
# 30 Mar 14:44    INFO  Saving current: saved/SASRec-Mar-30-2022_13-39-54.pth
# Saving current: saved/SASRec-Mar-30-2022_13-39-54.pth
# Saving current: saved/SASRec-Mar-30-2022_13-39-54.pth
# Train     4: 100%|█████████████████████| 4837/4837 [16:02<00:00,  5.02it/s, GPU RAM: 7.33 G/15.78 G]
# 30 Mar 15:00    INFO  epoch 4 training [time: 962.72s, train loss: 39730.6588]
# epoch 4 training [time: 962.72s, train loss: 39730.6588]
# epoch 4 training [time: 962.72s, train loss: 39730.6588]
# 30 Mar 15:00    INFO  Saving current: saved/SASRec-Mar-30-2022_13-39-54.pth
# Saving current: saved/SASRec-Mar-30-2022_13-39-54.pth
# Saving current: saved/SASRec-Mar-30-2022_13-39-54.pth
# Train     5: 100%|█████████████████████| 4837/4837 [16:05<00:00,  5.01it/s, GPU RAM: 7.33 G/15.78 G]
# 30 Mar 15:16    INFO  epoch 5 training [time: 965.06s, train loss: 39656.4236]
# epoch 5 training [time: 965.06s, train loss: 39656.4236]
# epoch 5 training [time: 965.06s, train loss: 39656.4236]
# 30 Mar 15:16    INFO  Saving current: saved/SASRec-Mar-30-2022_13-39-54.pth
# Saving current: saved/SASRec-Mar-30-2022_13-39-54.pth
# Saving current: saved/SASRec-Mar-30-2022_13-39-54.pth
# Train     6: 100%|█████████████████████| 4837/4837 [16:04<00:00,  5.01it/s, GPU RAM: 7.33 G/15.78 G]
# 30 Mar 15:32    INFO  epoch 6 training [time: 964.70s, train loss: 39602.3296]
# epoch 6 training [time: 964.70s, train loss: 39602.3296]
# epoch 6 training [time: 964.70s, train loss: 39602.3296]
# 30 Mar 15:32    INFO  Saving current: saved/SASRec-Mar-30-2022_13-39-54.pth
# Saving current: saved/SASRec-Mar-30-2022_13-39-54.pth
# Saving current: saved/SASRec-Mar-30-2022_13-39-54.pth
# Train     7: 100%|█████████████████████| 4837/4837 [16:00<00:00,  5.04it/s, GPU RAM: 7.33 G/15.78 G]
# 30 Mar 15:48    INFO  epoch 7 training [time: 960.62s, train loss: 39558.9740]
# epoch 7 training [time: 960.62s, train loss: 39558.9740]
# epoch 7 training [time: 960.62s, train loss: 39558.9740]
# 30 Mar 15:48    INFO  Saving current: saved/SASRec-Mar-30-2022_13-39-54.pth
# Saving current: saved/SASRec-Mar-30-2022_13-39-54.pth
# Saving current: saved/SASRec-Mar-30-2022_13-39-54.pth
# Train     8: 100%|█████████████████████| 4837/4837 [16:01<00:00,  5.03it/s, GPU RAM: 7.33 G/15.78 G]
# 30 Mar 16:04    INFO  epoch 8 training [time: 961.06s, train loss: 39522.5505]
# epoch 8 training [time: 961.06s, train loss: 39522.5505]
# epoch 8 training [time: 961.06s, train loss: 39522.5505]
# 30 Mar 16:04    INFO  Saving current: saved/SASRec-Mar-30-2022_13-39-54.pth
# Saving current: saved/SASRec-Mar-30-2022_13-39-54.pth
# Saving current: saved/SASRec-Mar-30-2022_13-39-54.pth
# Train     9: 100%|█████████████████████| 4837/4837 [15:59<00:00,  5.04it/s, GPU RAM: 7.33 G/15.78 G]
# 30 Mar 16:20    INFO  epoch 9 training [time: 959.62s, train loss: 39496.3533]
# epoch 9 training [time: 959.62s, train loss: 39496.3533]
# epoch 9 training [time: 959.62s, train loss: 39496.3533]
# 30 Mar 16:20    INFO  Saving current: saved/SASRec-Mar-30-2022_13-39-54.pth
# Saving current: saved/SASRec-Mar-30-2022_13-39-54.pth
# Saving current: saved/SASRec-Mar-30-2022_13-39-54.pth
# Train    10: 100%|█████████████████████| 4837/4837 [16:00<00:00,  5.03it/s, GPU RAM: 7.33 G/15.78 G]
# 30 Mar 16:36    INFO  epoch 10 training [time: 960.88s, train loss: 39467.2320]
# epoch 10 training [time: 960.88s, train loss: 39467.2320]
# epoch 10 training [time: 960.88s, train loss: 39467.2320]
# 30 Mar 16:36    INFO  Saving current: saved/SASRec-Mar-30-2022_13-39-54.pth
# Saving current: saved/SASRec-Mar-30-2022_13-39-54.pth
# Saving current: saved/SASRec-Mar-30-2022_13-39-54.pth
# Train    11: 100%|█████████████████████| 4837/4837 [16:00<00:00,  5.03it/s, GPU RAM: 7.33 G/15.78 G]
# 30 Mar 16:52    INFO  epoch 11 training [time: 960.77s, train loss: 39447.2663]
# epoch 11 training [time: 960.77s, train loss: 39447.2663]
# epoch 11 training [time: 960.77s, train loss: 39447.2663]
# 30 Mar 16:52    INFO  Saving current: saved/SASRec-Mar-30-2022_13-39-54.pth
# Saving current: saved/SASRec-Mar-30-2022_13-39-54.pth
# Saving current: saved/SASRec-Mar-30-2022_13-39-54.pth
# Train    12: 100%|█████████████████████| 4837/4837 [15:54<00:00,  5.07it/s, GPU RAM: 7.33 G/15.78 G]
# 30 Mar 17:08    INFO  epoch 12 training [time: 954.86s, train loss: 39427.5368]
# epoch 12 training [time: 954.86s, train loss: 39427.5368]
# epoch 12 training [time: 954.86s, train loss: 39427.5368]
# 30 Mar 17:08    INFO  Saving current: saved/SASRec-Mar-30-2022_13-39-54.pth
# Saving current: saved/SASRec-Mar-30-2022_13-39-54.pth
# Saving current: saved/SASRec-Mar-30-2022_13-39-54.pth
# Train    13: 100%|█████████████████████| 4837/4837 [15:57<00:00,  5.05it/s, GPU RAM: 7.33 G/15.78 G]
# 30 Mar 17:24    INFO  epoch 13 training [time: 958.01s, train loss: 39410.7149]
# epoch 13 training [time: 958.01s, train loss: 39410.7149]
# epoch 13 training [time: 958.01s, train loss: 39410.7149]
# 30 Mar 17:24    INFO  Saving current: saved/SASRec-Mar-30-2022_13-39-54.pth
# Saving current: saved/SASRec-Mar-30-2022_13-39-54.pth
# Saving current: saved/SASRec-Mar-30-2022_13-39-54.pth
# Train    14: 100%|█████████████████████| 4837/4837 [15:49<00:00,  5.10it/s, GPU RAM: 7.33 G/15.78 G]
# 30 Mar 17:40    INFO  epoch 14 training [time: 949.23s, train loss: 39397.6575]
# epoch 14 training [time: 949.23s, train loss: 39397.6575]
# epoch 14 training [time: 949.23s, train loss: 39397.6575]
# 30 Mar 17:40    INFO  Saving current: saved/SASRec-Mar-30-2022_13-39-54.pth
# Saving current: saved/SASRec-Mar-30-2022_13-39-54.pth
# Saving current: saved/SASRec-Mar-30-2022_13-39-54.pth
# Train    15: 100%|█████████████████████| 4837/4837 [16:01<00:00,  5.03it/s, GPU RAM: 7.33 G/15.78 G]
# 30 Mar 17:56    INFO  epoch 15 training [time: 961.32s, train loss: 39383.1034]
# epoch 15 training [time: 961.32s, train loss: 39383.1034]
# epoch 15 training [time: 961.32s, train loss: 39383.1034]
# 30 Mar 17:56    INFO  Saving current: saved/SASRec-Mar-30-2022_13-39-54.pth
# Saving current: saved/SASRec-Mar-30-2022_13-39-54.pth
# Saving current: saved/SASRec-Mar-30-2022_13-39-54.pth
# Train    16: 100%|█████████████████████| 4837/4837 [16:04<00:00,  5.01it/s, GPU RAM: 7.33 G/15.78 G]
# 30 Mar 18:12    INFO  epoch 16 training [time: 964.73s, train loss: 39369.1404]
# epoch 16 training [time: 964.73s, train loss: 39369.1404]
# epoch 16 training [time: 964.73s, train loss: 39369.1404]
# 30 Mar 18:12    INFO  Saving current: saved/SASRec-Mar-30-2022_13-39-54.pth
# Saving current: saved/SASRec-Mar-30-2022_13-39-54.pth
# Saving current: saved/SASRec-Mar-30-2022_13-39-54.pth
# Train    17: 100%|█████████████████████| 4837/4837 [15:59<00:00,  5.04it/s, GPU RAM: 7.33 G/15.78 G]
# 30 Mar 18:28    INFO  epoch 17 training [time: 959.54s, train loss: 39361.8770]
# epoch 17 training [time: 959.54s, train loss: 39361.8770]
# epoch 17 training [time: 959.54s, train loss: 39361.8770]
# 30 Mar 18:28    INFO  Saving current: saved/SASRec-Mar-30-2022_13-39-54.pth
# Saving current: saved/SASRec-Mar-30-2022_13-39-54.pth
# Saving current: saved/SASRec-Mar-30-2022_13-39-54.pth
# Train    18: 100%|█████████████████████| 4837/4837 [15:48<00:00,  5.10it/s, GPU RAM: 7.33 G/15.78 G]
# 30 Mar 18:44    INFO  epoch 18 training [time: 948.71s, train loss: 39350.2734]
# epoch 18 training [time: 948.71s, train loss: 39350.2734]
# epoch 18 training [time: 948.71s, train loss: 39350.2734]
# 30 Mar 18:44    INFO  Saving current: saved/SASRec-Mar-30-2022_13-39-54.pth
# Saving current: saved/SASRec-Mar-30-2022_13-39-54.pth
# Saving current: saved/SASRec-Mar-30-2022_13-39-54.pth
# Train    19: 100%|█████████████████████| 4837/4837 [15:45<00:00,  5.11it/s, GPU RAM: 7.33 G/15.78 G]
# 30 Mar 18:59    INFO  epoch 19 training [time: 945.68s, train loss: 39341.4081]
# epoch 19 training [time: 945.68s, train loss: 39341.4081]
# epoch 19 training [time: 945.68s, train loss: 39341.4081]
# 30 Mar 18:59    INFO  Saving current: saved/SASRec-Mar-30-2022_13-39-54.pth
# Saving current: saved/SASRec-Mar-30-2022_13-39-54.pth
# Saving current: saved/SASRec-Mar-30-2022_13-39-54.pth
# Train    20: 100%|█████████████████████| 4837/4837 [15:39<00:00,  5.15it/s, GPU RAM: 7.33 G/15.78 G]
# 30 Mar 19:15    INFO  epoch 20 training [time: 939.22s, train loss: 39332.8163]
# epoch 20 training [time: 939.22s, train loss: 39332.8163]
# epoch 20 training [time: 939.22s, train loss: 39332.8163]
# 30 Mar 19:15    INFO  Saving current: saved/SASRec-Mar-30-2022_13-39-54.pth
# Saving current: saved/SASRec-Mar-30-2022_13-39-54.pth
# Saving current: saved/SASRec-Mar-30-2022_13-39-54.pth
# Train    21: 100%|█████████████████████| 4837/4837 [15:50<00:00,  5.09it/s, GPU RAM: 7.33 G/15.78 G]
# 30 Mar 19:31    INFO  epoch 21 training [time: 950.26s, train loss: 39323.6351]
# epoch 21 training [time: 950.26s, train loss: 39323.6351]
# epoch 21 training [time: 950.26s, train loss: 39323.6351]
# 30 Mar 19:31    INFO  Saving current: saved/SASRec-Mar-30-2022_13-39-54.pth
# Saving current: saved/SASRec-Mar-30-2022_13-39-54.pth
# Saving current: saved/SASRec-Mar-30-2022_13-39-54.pth
# Train    22: 100%|█████████████████████| 4837/4837 [15:56<00:00,  5.05it/s, GPU RAM: 7.33 G/15.78 G]
# 30 Mar 19:47    INFO  epoch 22 training [time: 957.01s, train loss: 39316.6319]
# epoch 22 training [time: 957.01s, train loss: 39316.6319]
# epoch 22 training [time: 957.01s, train loss: 39316.6319]
# 30 Mar 19:47    INFO  Saving current: saved/SASRec-Mar-30-2022_13-39-54.pth
# Saving current: saved/SASRec-Mar-30-2022_13-39-54.pth
# Saving current: saved/SASRec-Mar-30-2022_13-39-54.pth
# Train    23: 100%|█████████████████████| 4837/4837 [15:57<00:00,  5.05it/s, GPU RAM: 7.33 G/15.78 G]
# 30 Mar 20:03    INFO  epoch 23 training [time: 957.36s, train loss: 39311.8473]
# epoch 23 training [time: 957.36s, train loss: 39311.8473]
# epoch 23 training [time: 957.36s, train loss: 39311.8473]
# 30 Mar 20:03    INFO  Saving current: saved/SASRec-Mar-30-2022_13-39-54.pth
# Saving current: saved/SASRec-Mar-30-2022_13-39-54.pth
# Saving current: saved/SASRec-Mar-30-2022_13-39-54.pth
# Train    24: 100%|█████████████████████| 4837/4837 [16:00<00:00,  5.04it/s, GPU RAM: 7.33 G/15.78 G]
# 30 Mar 20:19    INFO  epoch 24 training [time: 960.35s, train loss: 39305.4238]
# epoch 24 training [time: 960.35s, train loss: 39305.4238]
# epoch 24 training [time: 960.35s, train loss: 39305.4238]
# 30 Mar 20:19    INFO  Saving current: saved/SASRec-Mar-30-2022_13-39-54.pth
# Saving current: saved/SASRec-Mar-30-2022_13-39-54.pth
# Saving current: saved/SASRec-Mar-30-2022_13-39-54.pth
# Train    25: 100%|█████████████████████| 4837/4837 [16:02<00:00,  5.03it/s, GPU RAM: 7.33 G/15.78 G]
# 30 Mar 20:35    INFO  epoch 25 training [time: 962.29s, train loss: 39299.9231]
# epoch 25 training [time: 962.29s, train loss: 39299.9231]
# epoch 25 training [time: 962.29s, train loss: 39299.9231]
# 30 Mar 20:35    INFO  Saving current: saved/SASRec-Mar-30-2022_13-39-54.pth
# Saving current: saved/SASRec-Mar-30-2022_13-39-54.pth
# Saving current: saved/SASRec-Mar-30-2022_13-39-54.pth
# Train    26: 100%|█████████████████████| 4837/4837 [15:55<00:00,  5.06it/s, GPU RAM: 7.33 G/15.78 G]
# 30 Mar 20:51    INFO  epoch 26 training [time: 955.66s, train loss: 39293.9050]
# epoch 26 training [time: 955.66s, train loss: 39293.9050]
# epoch 26 training [time: 955.66s, train loss: 39293.9050]
# 30 Mar 20:51    INFO  Saving current: saved/SASRec-Mar-30-2022_13-39-54.pth
# Saving current: saved/SASRec-Mar-30-2022_13-39-54.pth
# Saving current: saved/SASRec-Mar-30-2022_13-39-54.pth
# Train    27: 100%|█████████████████████| 4837/4837 [16:00<00:00,  5.03it/s, GPU RAM: 7.33 G/15.78 G]
# 30 Mar 21:07    INFO  epoch 27 training [time: 960.97s, train loss: 39287.2052]
# epoch 27 training [time: 960.97s, train loss: 39287.2052]
# epoch 27 training [time: 960.97s, train loss: 39287.2052]
# 30 Mar 21:07    INFO  Saving current: saved/SASRec-Mar-30-2022_13-39-54.pth
# Saving current: saved/SASRec-Mar-30-2022_13-39-54.pth
# Saving current: saved/SASRec-Mar-30-2022_13-39-54.pth
# Train    28: 100%|█████████████████████| 4837/4837 [16:00<00:00,  5.03it/s, GPU RAM: 7.33 G/15.78 G]
# 30 Mar 21:23    INFO  epoch 28 training [time: 960.80s, train loss: 39282.9840]
# epoch 28 training [time: 960.80s, train loss: 39282.9840]
# epoch 28 training [time: 960.80s, train loss: 39282.9840]
# 30 Mar 21:23    INFO  Saving current: saved/SASRec-Mar-30-2022_13-39-54.pth
# Saving current: saved/SASRec-Mar-30-2022_13-39-54.pth
# Saving current: saved/SASRec-Mar-30-2022_13-39-54.pth
# Train    29: 100%|█████████████████████| 4837/4837 [15:58<00:00,  5.04it/s, GPU RAM: 7.33 G/15.78 G]
# 30 Mar 21:39    INFO  epoch 29 training [time: 958.93s, train loss: 39278.5461]
# epoch 29 training [time: 958.93s, train loss: 39278.5461]
# epoch 29 training [time: 958.93s, train loss: 39278.5461]
# 30 Mar 21:39    INFO  Saving current: saved/SASRec-Mar-30-2022_13-39-54.pth
# Saving current: saved/SASRec-Mar-30-2022_13-39-54.pth
# Saving current: saved/SASRec-Mar-30-2022_13-39-54.pth
# Train    30: 100%|█████████████████████| 4837/4837 [16:00<00:00,  5.04it/s, GPU RAM: 7.33 G/15.78 G]
# 30 Mar 21:55    INFO  epoch 30 training [time: 960.36s, train loss: 39274.2634]
# epoch 30 training [time: 960.36s, train loss: 39274.2634]
# epoch 30 training [time: 960.36s, train loss: 39274.2634]
# 30 Mar 21:55    INFO  Saving current: saved/SASRec-Mar-30-2022_13-39-54.pth
# Saving current: saved/SASRec-Mar-30-2022_13-39-54.pth
# Saving current: saved/SASRec-Mar-30-2022_13-39-54.pth
# Train    31: 100%|█████████████████████| 4837/4837 [15:59<00:00,  5.04it/s, GPU RAM: 7.33 G/15.78 G]
# 30 Mar 22:11    INFO  epoch 31 training [time: 959.71s, train loss: 39271.9207]
# epoch 31 training [time: 959.71s, train loss: 39271.9207]
# epoch 31 training [time: 959.71s, train loss: 39271.9207]
# 30 Mar 22:11    INFO  Saving current: saved/SASRec-Mar-30-2022_13-39-54.pth
# Saving current: saved/SASRec-Mar-30-2022_13-39-54.pth
# Saving current: saved/SASRec-Mar-30-2022_13-39-54.pth
# Train    32: 100%|█████████████████████| 4837/4837 [16:01<00:00,  5.03it/s, GPU RAM: 7.33 G/15.78 G]
# 30 Mar 22:27    INFO  epoch 32 training [time: 961.16s, train loss: 39266.4624]
# epoch 32 training [time: 961.16s, train loss: 39266.4624]
# epoch 32 training [time: 961.16s, train loss: 39266.4624]
# 30 Mar 22:27    INFO  Saving current: saved/SASRec-Mar-30-2022_13-39-54.pth
# Saving current: saved/SASRec-Mar-30-2022_13-39-54.pth
# Saving current: saved/SASRec-Mar-30-2022_13-39-54.pth
# Train    33: 100%|█████████████████████| 4837/4837 [15:56<00:00,  5.06it/s, GPU RAM: 7.33 G/15.78 G]
# 30 Mar 22:43    INFO  epoch 33 training [time: 956.08s, train loss: 39264.5694]
# epoch 33 training [time: 956.08s, train loss: 39264.5694]
# epoch 33 training [time: 956.08s, train loss: 39264.5694]
# 30 Mar 22:43    INFO  Saving current: saved/SASRec-Mar-30-2022_13-39-54.pth
# Saving current: saved/SASRec-Mar-30-2022_13-39-54.pth
# Saving current: saved/SASRec-Mar-30-2022_13-39-54.pth
# Train    34: 100%|█████████████████████| 4837/4837 [15:57<00:00,  5.05it/s, GPU RAM: 7.33 G/15.78 G]
# 30 Mar 22:59    INFO  epoch 34 training [time: 957.65s, train loss: 39261.8457]
# epoch 34 training [time: 957.65s, train loss: 39261.8457]
# epoch 34 training [time: 957.65s, train loss: 39261.8457]
# 30 Mar 22:59    INFO  Saving current: saved/SASRec-Mar-30-2022_13-39-54.pth
# Saving current: saved/SASRec-Mar-30-2022_13-39-54.pth
# Saving current: saved/SASRec-Mar-30-2022_13-39-54.pth
# Train    35: 100%|█████████████████████| 4837/4837 [15:57<00:00,  5.05it/s, GPU RAM: 7.33 G/15.78 G]
# 30 Mar 23:15    INFO  epoch 35 training [time: 957.37s, train loss: 39258.1649]
# epoch 35 training [time: 957.37s, train loss: 39258.1649]
# epoch 35 training [time: 957.37s, train loss: 39258.1649]
# 30 Mar 23:15    INFO  Saving current: saved/SASRec-Mar-30-2022_13-39-54.pth
# Saving current: saved/SASRec-Mar-30-2022_13-39-54.pth
# Saving current: saved/SASRec-Mar-30-2022_13-39-54.pth
# Train    36: 100%|█████████████████████| 4837/4837 [15:56<00:00,  5.06it/s, GPU RAM: 7.33 G/15.78 G]
# 30 Mar 23:31    INFO  epoch 36 training [time: 956.42s, train loss: 39255.2540]
# epoch 36 training [time: 956.42s, train loss: 39255.2540]
# epoch 36 training [time: 956.42s, train loss: 39255.2540]
# 30 Mar 23:31    INFO  Saving current: saved/SASRec-Mar-30-2022_13-39-54.pth
# Saving current: saved/SASRec-Mar-30-2022_13-39-54.pth
# Saving current: saved/SASRec-Mar-30-2022_13-39-54.pth
# Train    37: 100%|█████████████████████| 4837/4837 [15:58<00:00,  5.05it/s, GPU RAM: 7.33 G/15.78 G]
# 30 Mar 23:47    INFO  epoch 37 training [time: 958.02s, train loss: 39249.7336]
# epoch 37 training [time: 958.02s, train loss: 39249.7336]
# epoch 37 training [time: 958.02s, train loss: 39249.7336]
# 30 Mar 23:47    INFO  Saving current: saved/SASRec-Mar-30-2022_13-39-54.pth
# Saving current: saved/SASRec-Mar-30-2022_13-39-54.pth
# Saving current: saved/SASRec-Mar-30-2022_13-39-54.pth
# Train    38: 100%|█████████████████████| 4837/4837 [15:59<00:00,  5.04it/s, GPU RAM: 7.33 G/15.78 G]
# 31 Mar 00:02    INFO  epoch 38 training [time: 959.76s, train loss: 39247.1500]
# epoch 38 training [time: 959.76s, train loss: 39247.1500]
# epoch 38 training [time: 959.76s, train loss: 39247.1500]
# 31 Mar 00:03    INFO  Saving current: saved/SASRec-Mar-30-2022_13-39-54.pth
# Saving current: saved/SASRec-Mar-30-2022_13-39-54.pth
# Saving current: saved/SASRec-Mar-30-2022_13-39-54.pth
# Train    39: 100%|█████████████████████| 4837/4837 [16:08<00:00,  4.99it/s, GPU RAM: 7.33 G/15.78 G]
# 31 Mar 00:19    INFO  epoch 39 training [time: 968.52s, train loss: 39243.9119]
# epoch 39 training [time: 968.52s, train loss: 39243.9119]
# epoch 39 training [time: 968.52s, train loss: 39243.9119]
# 31 Mar 00:19    INFO  Saving current: saved/SASRec-Mar-30-2022_13-39-54.pth
# Saving current: saved/SASRec-Mar-30-2022_13-39-54.pth
# Saving current: saved/SASRec-Mar-30-2022_13-39-54.pth
# Train    40: 100%|█████████████████████| 4837/4837 [16:07<00:00,  5.00it/s, GPU RAM: 7.33 G/15.78 G]
# 31 Mar 00:35    INFO  epoch 40 training [time: 967.34s, train loss: 39242.3688]
# epoch 40 training [time: 967.34s, train loss: 39242.3688]
# epoch 40 training [time: 967.34s, train loss: 39242.3688]
# 31 Mar 00:35    INFO  Saving current: saved/SASRec-Mar-30-2022_13-39-54.pth
# Saving current: saved/SASRec-Mar-30-2022_13-39-54.pth
# Saving current: saved/SASRec-Mar-30-2022_13-39-54.pth
# Train    41: 100%|█████████████████████| 4837/4837 [16:02<00:00,  5.02it/s, GPU RAM: 7.33 G/15.78 G]
# 31 Mar 00:51    INFO  epoch 41 training [time: 962.78s, train loss: 39240.9320]
# epoch 41 training [time: 962.78s, train loss: 39240.9320]
# epoch 41 training [time: 962.78s, train loss: 39240.9320]
# 31 Mar 00:51    INFO  Saving current: saved/SASRec-Mar-30-2022_13-39-54.pth
# Saving current: saved/SASRec-Mar-30-2022_13-39-54.pth
# Saving current: saved/SASRec-Mar-30-2022_13-39-54.pth
# Train    42: 100%|█████████████████████| 4837/4837 [16:07<00:00,  5.00it/s, GPU RAM: 7.33 G/15.78 G]
# 31 Mar 01:07    INFO  epoch 42 training [time: 967.29s, train loss: 39236.1359]
# epoch 42 training [time: 967.29s, train loss: 39236.1359]
# epoch 42 training [time: 967.29s, train loss: 39236.1359]
# 31 Mar 01:07    INFO  Saving current: saved/SASRec-Mar-30-2022_13-39-54.pth
# Saving current: saved/SASRec-Mar-30-2022_13-39-54.pth
# Saving current: saved/SASRec-Mar-30-2022_13-39-54.pth
# Train    43: 100%|█████████████████████| 4837/4837 [16:13<00:00,  4.97it/s, GPU RAM: 7.33 G/15.78 G]
# 31 Mar 01:23    INFO  epoch 43 training [time: 973.67s, train loss: 39234.6531]
# epoch 43 training [time: 973.67s, train loss: 39234.6531]
# epoch 43 training [time: 973.67s, train loss: 39234.6531]
# 31 Mar 01:23    INFO  Saving current: saved/SASRec-Mar-30-2022_13-39-54.pth
# Saving current: saved/SASRec-Mar-30-2022_13-39-54.pth
# Saving current: saved/SASRec-Mar-30-2022_13-39-54.pth
# Train    44: 100%|█████████████████████| 4837/4837 [16:13<00:00,  4.97it/s, GPU RAM: 7.33 G/15.78 G]
# 31 Mar 01:39    INFO  epoch 44 training [time: 973.21s, train loss: 39230.7490]
# epoch 44 training [time: 973.21s, train loss: 39230.7490]
# epoch 44 training [time: 973.21s, train loss: 39230.7490]
# 31 Mar 01:39    INFO  Saving current: saved/SASRec-Mar-30-2022_13-39-54.pth
# Saving current: saved/SASRec-Mar-30-2022_13-39-54.pth
# Saving current: saved/SASRec-Mar-30-2022_13-39-54.pth
# Train    45: 100%|█████████████████████| 4837/4837 [16:08<00:00,  5.00it/s, GPU RAM: 7.33 G/15.78 G]
# 31 Mar 01:56    INFO  epoch 45 training [time: 968.25s, train loss: 39227.6397]
# epoch 45 training [time: 968.25s, train loss: 39227.6397]
# epoch 45 training [time: 968.25s, train loss: 39227.6397]
# 31 Mar 01:56    INFO  Saving current: saved/SASRec-Mar-30-2022_13-39-54.pth
# Saving current: saved/SASRec-Mar-30-2022_13-39-54.pth
# Saving current: saved/SASRec-Mar-30-2022_13-39-54.pth
# Train    46: 100%|█████████████████████| 4837/4837 [15:59<00:00,  5.04it/s, GPU RAM: 7.33 G/15.78 G]
# 31 Mar 02:12    INFO  epoch 46 training [time: 959.60s, train loss: 39227.4931]
# epoch 46 training [time: 959.60s, train loss: 39227.4931]
# epoch 46 training [time: 959.60s, train loss: 39227.4931]
# 31 Mar 02:12    INFO  Saving current: saved/SASRec-Mar-30-2022_13-39-54.pth
# Saving current: saved/SASRec-Mar-30-2022_13-39-54.pth
# Saving current: saved/SASRec-Mar-30-2022_13-39-54.pth
# Train    47: 100%|█████████████████████| 4837/4837 [15:57<00:00,  5.05it/s, GPU RAM: 7.33 G/15.78 G]
# 31 Mar 02:27    INFO  epoch 47 training [time: 957.12s, train loss: 39225.2896]
# epoch 47 training [time: 957.12s, train loss: 39225.2896]
# epoch 47 training [time: 957.12s, train loss: 39225.2896]
# 31 Mar 02:27    INFO  Saving current: saved/SASRec-Mar-30-2022_13-39-54.pth
# Saving current: saved/SASRec-Mar-30-2022_13-39-54.pth
# Saving current: saved/SASRec-Mar-30-2022_13-39-54.pth
# Train    48: 100%|█████████████████████| 4837/4837 [16:00<00:00,  5.04it/s, GPU RAM: 7.33 G/15.78 G]
# 31 Mar 02:43    INFO  epoch 48 training [time: 960.05s, train loss: 39222.7792]
# epoch 48 training [time: 960.05s, train loss: 39222.7792]
# epoch 48 training [time: 960.05s, train loss: 39222.7792]
# 31 Mar 02:43    INFO  Saving current: saved/SASRec-Mar-30-2022_13-39-54.pth
# Saving current: saved/SASRec-Mar-30-2022_13-39-54.pth
# Saving current: saved/SASRec-Mar-30-2022_13-39-54.pth
# Train    49: 100%|█████████████████████| 4837/4837 [15:56<00:00,  5.06it/s, GPU RAM: 7.33 G/15.78 G]
# 31 Mar 02:59    INFO  epoch 49 training [time: 956.80s, train loss: 39220.7051]
# epoch 49 training [time: 956.80s, train loss: 39220.7051]
# epoch 49 training [time: 956.80s, train loss: 39220.7051]
# 31 Mar 02:59    INFO  Saving current: saved/SASRec-Mar-30-2022_13-39-54.pth
# Saving current: saved/SASRec-Mar-30-2022_13-39-54.pth
# Saving current: saved/SASRec-Mar-30-2022_13-39-54.pth

# %%
from recbole.utils.case_study import full_sort_topk

external_user_ids = dataset.id2token(dataset.uid_field, list(range(dataset.user_num)))[1:]

topk_items = []
for internal_user_id in tqdm(list(range(dataset.user_num))[1:]):
    _, topk_iid_list = full_sort_topk([internal_user_id], model, test_data, k=12, device=config['device'])
    last_topk_iid_list = topk_iid_list[-1]
    external_item_list = dataset.id2token(dataset.iid_field, last_topk_iid_list.cpu()).tolist()
    topk_items.append(external_item_list)
# Out:
# 100%|██████████| 306732/306732 [27:54<00:00, 183.16it/s]

# %%
external_item_str = [' '.join(x) for x in topk_items]
result = pd.DataFrame(external_user_ids, columns=['customer_id'])
result['prediction'] = external_item_str
result.head()
# Out:
#                                          customer_id  \
# 0  00007d2de826758b65a93dd24ce629ed66842531df6699...
# 1  0008968c0d451dbc5a9968da03196fe20051965edde741...
# 2  000aa7f0dc06cd7174389e76c9e132a67860c5f65f9706...
# 3  001127bffdda108579e6cb16080440e89bf1250a776c6e...
# 4  001ea4e9c54f7e9c88811260d954edc059d596147e1cf8...
#
#                                           prediction
# 0  554757003 816914001 629551003 509210020 509210...
# 1  857163001 751664001 868134001 863595006 768912...
# 2  851996001 861036001 851996002 871957001 861036...
# 3  879965001 879965002 803772002 863937003 817472...
# 4  739590032 860949002 838055002 846279001 351484...

# %%
submission = pd.read_csv(PROCESSED / 'lstm_ensemble.csv')
submission = pd.merge(submission, result, on='customer_id', how='outer')
submission = submission.fillna(-1)
submission['prediction'] = submission.apply(
    lambda x: x['prediction_y'] if x['prediction_y'] != -1 else x['prediction_x'], axis=1)

# %%
external_item_str = [' '.join(x) for x in topk_items]
result = pd.DataFrame(external_user_ids, columns=['customer_id'])
result['prediction'] = external_item_str
result.head()
# Out:
#                                          customer_id  \
# 0  00007d2de826758b65a93dd24ce629ed66842531df6699...
# 1  0008968c0d451dbc5a9968da03196fe20051965edde741...
# 2  000aa7f0dc06cd7174389e76c9e132a67860c5f65f9706...
# 3  001127bffdda108579e6cb16080440e89bf1250a776c6e...
# 4  001ea4e9c54f7e9c88811260d954edc059d596147e1cf8...
#
#                                           prediction
# 0  554757003 484398001 768912001 179123001 720125...
# 1  863595006 904545002 883307004 921906003 868134...
# 2  851996001 827968004 714790020 706016001 803468...
# 3  706016001 749699002 762846001 762846008 706016...
# 4  739590032 860949002 860949003 846279001 811835...

# %%
submission = submission.drop(columns=['prediction_y', 'prediction_x'])
submission.head()
# Out:
#                                          customer_id  \
# 0  00000dbacae5abe5e23885899a1fa44253a17956c6d1c3...
# 1  0000423b00ade91418cceaf3b26c6af3dd342b51fd051e...
# 2  000058a12d5b43e67d225668fa1f8d618c13dc232df0ca...
# 3  00005ca1c9ed5f5146b52ac8639a40ca9d57aeff4d1bd2...
# 4  00006413d8573cd20ed7128e53b7b13819fe5cfc2d801f...
#
#                                           prediction
# 0  0568601043 0568601006 0656719005 0745232001 07...
# 1  351484002 838055003 723529001 699080001 599580...
# 2  0794321007 0852643001 0852643003 0858883002 09...
# 3  0448509014 0924243001 0573085028 0751471001 09...
# 4  0730683050 0924243001 0791587015 0896152002 09...

# %%
submission.to_csv(SUBMISSION / 'sasrec.csv', index=False)
