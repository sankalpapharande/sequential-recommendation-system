# %%
import os
from pathlib import Path

os.chdir('/content/drive/MyDrive/hnm')
DATA_PATH = Path.cwd() / 'data'
RAW = DATA_PATH / 'raw'
PROCESSED = DATA_PATH / 'processed'
SUBMISSION = DATA_PATH / 'submission'

# %%
# !pip install kaggle

# %%
# !mkdir ~/.kaggle

# %%
# !cp kaggle.json ~/.kaggle/

# %%
# !chmod 600 ~/.kaggle/kaggle.json

# %%
# !kaggle competitions download -c h-and-m-personalized-fashion-recommendations -p {RAW}
# Out:
# ...
# 100% 28.7G/28.7G [09:28<00:00, 91.7MB/s]
# 100% 28.7G/28.7G [09:28<00:00, 54.2MB/s]

# %%
# !unzip {RAW / 'h-and-m-personalized-fashion-recommendations.zip'} -d {RAW}
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: /content/drive/MyDrive/hnm/data/raw/images/089/0890677001.jpg
#   inflating: /content/drive/MyDrive/hnm/data/raw/images/089/0890677002.jpg
#   inflating: /content/drive/MyDrive/hnm/data/raw/images/089/0890677004.jpg
#   inflating: /content/drive/MyDrive/hnm/data/raw/images/089/0890683001.jpg
#   inflating: /content/drive/MyDrive/hnm/data/raw/images/089/0890683002.jpg
#   inflating: /content/drive/MyDrive/hnm/data/raw/images/089/0890684001.jpg
#   inflating: /content/drive/MyDrive/hnm/data/raw/images/089/0890684002.jpg
#   inflating: /content/drive/MyDrive/hnm/data/raw/images/089/0890686002.jpg
#   inflating: /content/drive/MyDrive/hnm/data/raw/images/089/0890697001.jpg
#   inflating: /content/drive/MyDrive/hnm/data/raw/images/089/0890697002.jpg
#   inflating: /content/drive/MyDrive/hnm/data/raw/images/089/0890700001.jpg
#   inflating: /content/drive/MyDrive/hnm/data/raw/images/089/0890717001.jpg
# ...
